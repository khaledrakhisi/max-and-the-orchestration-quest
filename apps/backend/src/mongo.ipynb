# %%
import logging
import logging.handlers
import json
import os
from datetime import datetime
import pymongo

MONGO_URI = "mongodb+srv://joanigaxhi1_db_user:6qKoKOtOXDO00lrT@cluster0.hfqth20.mongodb.net/"
client = pymongo.MongoClient(MONGO_URI)

# %%
def get_users(client):
    db = client["max"]
    return db["users"]

# %%
client = pymongo.MongoClient(MONGO_URI)
db = client["logs"]
collection = db["app_logs"]

# insert a test document to verify connection
collection.insert_one({"test_connection": True, "timestamp": datetime.utcnow()})
# Out:
# InsertOneResult(ObjectId('6944371544687ad03654ab1b'), acknowledged=True)

# %%
def get_logs_collection(client):
    db = client["logs"]
    return db["app_logs"]

a = get_logs_collection(client)
print(a.find_one())
# Out:
# {'_id': ObjectId('6944365f44687ad03654ab13'), 'test_connection': True, 'timestamp': datetime.datetime(2025, 12, 18, 17, 14, 7, 879000)}

# %%
import users

# Dependency Injection: we create the collection once and pass it around
users_col = users.get_db_collection()

user1 = users.User(username="max", email="dddd", password="hashed_password_123")
user_id = users.insert_user(users_col, user1)
print(f"Created user with ID: {user_id}")
# Out:
# Created user with ID: 694453d731db9b46d22bf281

# %%
import users
userdd = users.insert_user(users_col, users.User(username="dd", email="dd", password="dd"))
userdd
# Out:
# '6944552431db9b46d22bf295'

# %%
from bson import ObjectId

print(f"Updated user: {users.find_user(users_col, {'_id': ObjectId(uid)})}")
# Out:
# Updated user: {'_id': ObjectId('69444f4e44687ad03654ab1e'), 'username': 'func_player', 'email': 'fp@example.com', 'password': 'secret', 'totalXP': 250, 'level': 2, 'badges': [{'badgeId': 'functional-pro', 'name': 'Functional Programmer', 'earnedAt': '2025-12-18T19:00:31.150970Z'}], 'createdAt': '2025-12-18T19:00:30.291169Z'}
